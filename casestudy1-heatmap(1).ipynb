# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Case Study 1
#
# This exercise is part of the project of the Google Data Analytics Professional Certification
# Below, we develop the heatmap that is part of the share phase of analysis.

# %%
# import geopandas 
import geopandas as gpd

# %% [markdown]
# This first dataset is about the start station for casual riders during the weekends for the period of analysis (04/2021-03/2022).
# The goal is to verify the area with most potential for advertisement (where most casual riders start the bike ride during the weekend).

# %%
# read in the data 
casual_start_station_weekend = pd.read_csv("/kaggle/input/start-station-casual-weekend/start_station_casual_weekend.csv")

# %%
#checking the data
casual_start_station_weekend.head()
#type(casual_start_station_weekend)

# %% [markdown]
# ## Creating the GeoDataFrame
# Now we are going to use the latitude and longitude to create a GeoDataFrame

# %%
# Convert the DataFrame to a GeoDataFrame
gpd_start_station_casual_weekend = gpd.GeoDataFrame(
    casual_start_station_weekend,
    geometry=gpd.points_from_xy(casual_start_station_weekend.start_lng, casual_start_station_weekend.start_lat))

# Set the coordinate reference system (CRS) to EPSG 4326
gpd_start_station_casual_weekend.crs = {'init': 'epsg:4326'}

gpd_start_station_casual_weekend.head()

# %%
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap

# %% [markdown]
# ## Creating the base map of Chicago

# %%
# Create a base map
Chicago_map = folium.Map(location=[41.87,-87.63], tiles='cartodbpositron', zoom_start=13)

Chicago_map

# %% [markdown]
# ## Adding the heatmap
# The heatmap represent the locations of the start stations the casual users collect the bike on weekends

# %%
# Add a heatmap to the base map
HeatMap(data=gpd_start_station_casual_weekend[['start_lat', 'start_lng']], radius=11).add_to(Chicago_map)

Chicago_map

# %% [markdown]
# The above interactive plot shows that there is a bigger concentration of casual riders starting theirs rides during the weekends in the areas of navy pier, lakefront trail, lake shore and millenium park. These areas are good for a marketing campaign aiming casual riders.

# %% [markdown]
# ## Creating the heatmap for the end stations most used by casual riders during the weekends.

# %%
# importing the dataset
casual_end_station_weekend = pd.read_csv("/kaggle/input/start-station-casual-weekend/start_station_casual_weekend.csv")

# %%
# Convert the DataFrame to a GeoDataFrame
gpd_end_station_casual_weekend = gpd.GeoDataFrame(
    casual_end_station_weekend,
    geometry=gpd.points_from_xy(casual_end_station_weekend.start_lng, casual_end_station_weekend.start_lat))

# Set the coordinate reference system (CRS) to EPSG 4326
gpd_end_station_casual_weekend.crs = {'init': 'epsg:4326'}

gpd_end_station_casual_weekend.head()

# %% [markdown]
# ## Creating the heatmap for the end station rides for casual users

# %%
# Create a base map
Chicago_map2 = folium.Map(location=[41.87,-87.63], tiles='cartodbpositron', zoom_start=13)

Chicago_map2

# Add a heatmap to the base map
HeatMap(data=gpd_end_station_casual_weekend[['start_lat', 'start_lng']], radius=11).add_to(Chicago_map2)

Chicago_map2

# %% [markdown]
# The end station use are very similar to the start stations for the casual riders during the weekends.

# %% [markdown]
# ## Creating the heatmap for the most used stations by casual riders during
# All days of the week have been included in the dataset

# %%
# Importing the dataset
start_station_casual_alldays = pd.read_csv("/kaggle/input/casual-stations-alldays/casual_station_alldays.csv")

# %% [markdown]
# ## Creating the GeoDataFrame
# Using GeoPandas

# %%
#Convert the DataFrame to a GeoDataFrame
gpd_start_station_casual_alldays = gpd.GeoDataFrame(
    start_station_casual_alldays,
    geometry=gpd.points_from_xy(start_station_casual_alldays.start_lng, start_station_casual_alldays.start_lat))

# Set the coordinate reference system (CRS) to EPSG 4326
gpd_start_station_casual_alldays.crs = {'init': 'epsg:4326'}

gpd_start_station_casual_alldays.head()

# %% [markdown]
# ## Adding the heatmaps with the start stations for the casual riders

# %%
# Create a base map
Chicago_map3 = folium.Map(location=[41.87,-87.63], tiles='cartodbpositron', zoom_start=13)

# Add a heatmap to the base map
HeatMap(data=gpd_start_station_casual_alldays[['start_lat', 'start_lng']], radius=11).add_to(Chicago_map3)

Chicago_map3

# %% [markdown]
# ## Creating the heatmap with the most used stations by the member riders
# All days of the week included in the dataset

# %%
#Importing the dataset

start_station_member_alldays = pd.read_csv("/kaggle/input/member-stations-alldays/member_station_alldays.csv")

# %% [markdown]
# ## Creating the GeoDataFrame
# with GeoPandas

# %%
#Convert the DataFrame to a GeoDataFrame
gpd_start_station_member_alldays = gpd.GeoDataFrame(
    start_station_member_alldays,
    geometry=gpd.points_from_xy(start_station_member_alldays.start_lng, start_station_member_alldays.start_lat))

# Set the coordinate reference system (CRS) to EPSG 4326
gpd_start_station_member_alldays.crs = {'init': 'epsg:4326'}

gpd_start_station_member_alldays.head()

# %% [markdown]
# ## Adding the heatmaps with the start stations for the members

# %%
# Create a base map
Chicago_map4 = folium.Map(location=[41.87,-87.63], tiles='cartodbpositron', zoom_start=13)

# Add a heatmap to the base map
HeatMap(data=gpd_start_station_member_alldays[['start_lat', 'start_lng']], radius=11).add_to(Chicago_map4)

Chicago_map4
